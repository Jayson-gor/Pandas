# %%
#importing data
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

oil_price_pd = pd.read_csv(r"C:\Users\gorja\Downloads\DP_LIVE_04012024131521834.csv")
oil_price_pd
# Out:
#     LOCATION    INDICATOR SUBJECT  MEASURE FREQUENCY  TIME   Value Flag Codes
# 0        AUS  OILIMPPRICE     TOT  USD_BAR         A  2019   70.21        NaN
# 1        AUS  OILIMPPRICE     TOT  USD_BAR         A  2020   50.21        NaN
# 2        AUS  OILIMPPRICE     TOT  USD_BAR         A  2021   72.04        NaN
# 3        AUS  OILIMPPRICE     TOT  USD_BAR         A  2022  110.68        NaN
# 4        AUT  OILIMPPRICE     TOT  USD_BAR         A  2019   64.52        NaN
# ..       ...          ...     ...      ...       ...   ...     ...        ...
# 111      LUX  OILIMPPRICE     TOT  USD_BAR         A  2022     NaN          M
# 112      LTU  OILIMPPRICE     TOT  USD_BAR         A  2019     NaN          L
# 113      LTU  OILIMPPRICE     TOT  USD_BAR         A  2020   37.65        NaN
# 114      LTU  OILIMPPRICE     TOT  USD_BAR         A  2021   70.33        NaN
# 115      LTU  OILIMPPRICE     TOT  USD_BAR         A  2022   93.48        NaN
#
# [116 rows x 8 columns]

# %%
#correcting the date format for time column
oil_price_pd['TIME'] = pd.to_datetime(oil_price_pd['TIME']).dt.year

# %%
#checking the format
oil_price_pd.dtypes
# Out:
# LOCATION       object
# INDICATOR      object
# SUBJECT        object
# MEASURE        object
# FREQUENCY      object
# TIME            int32
# Value         float64
# Flag Codes     object
# dtype: object

# %%
#checking duplicates
print(oil_price_pd.duplicated())
print(oil_price_pd.info())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 111     True
# 112    False
# 113    False
# 114    False
# 115    False
# Length: 116, dtype: bool
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    116 non-null    object
#  1   INDICATOR   116 non-null    object
#  2   SUBJECT     116 non-null    object
#  3   MEASURE     116 non-null    object
#  4   FREQUENCY   116 non-null    object
#  5   TIME        116 non-null    int32
#  6   Value       107 non-null    float64
#  7   Flag Codes  9 non-null      object
# dtypes: float64(1), int32(1), object(6)
# memory usage: 6.9+ KB
# None

# %%
#removing duplicates
oil_price_pd.drop_duplicates(inplace = True)
print(oil_price_pd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110 entries, 0 to 115
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    110 non-null    object
#  1   INDICATOR   110 non-null    object
#  2   SUBJECT     110 non-null    object
#  3   MEASURE     110 non-null    object
#  4   FREQUENCY   110 non-null    object
#  5   TIME        110 non-null    int32
#  6   Value       107 non-null    float64
#  7   Flag Codes  3 non-null      object
# dtypes: float64(1), int32(1), object(6)
# memory usage: 7.3+ KB
# None

# %%
#dropping non essential columns
oil_price_pd.drop(columns = ['INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'])
# Out:
#     LOCATION  TIME   Value
# 0        AUS  1970   70.21
# 1        AUS  1970   50.21
# 2        AUS  1970   72.04
# 3        AUS  1970  110.68
# 4        AUT  1970   64.52
# ..       ...   ...     ...
# 108      LUX  1970     NaN
# 112      LTU  1970     NaN
# 113      LTU  1970   37.65
# 114      LTU  1970   70.33
# 115      LTU  1970   93.48
#
# [110 rows x 3 columns]

# %%
oil_price_pd['Value'].fillna(0, inplace = True)

# %%
oil_price_pd
# Out:
#     LOCATION    INDICATOR SUBJECT  MEASURE FREQUENCY  TIME   Value Flag Codes
# 0        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970   70.21        NaN
# 1        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970   50.21        NaN
# 2        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970   72.04        NaN
# 3        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970  110.68        NaN
# 4        AUT  OILIMPPRICE     TOT  USD_BAR         A  1970   64.52        NaN
# ..       ...          ...     ...      ...       ...   ...     ...        ...
# 108      LUX  OILIMPPRICE     TOT  USD_BAR         A  1970    0.00          M
# 112      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970    0.00          L
# 113      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970   37.65        NaN
# 114      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970   70.33        NaN
# 115      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970   93.48        NaN
#
# [110 rows x 8 columns]

# %%
oil_price_pd['Value'].fillna(0, inplace = True)
oil_price_pd
# Out:
#     LOCATION    INDICATOR SUBJECT  MEASURE FREQUENCY  TIME   Value Flag Codes
# 0        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970   70.21        NaN
# 1        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970   50.21        NaN
# 2        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970   72.04        NaN
# 3        AUS  OILIMPPRICE     TOT  USD_BAR         A  1970  110.68        NaN
# 4        AUT  OILIMPPRICE     TOT  USD_BAR         A  1970   64.52        NaN
# ..       ...          ...     ...      ...       ...   ...     ...        ...
# 108      LUX  OILIMPPRICE     TOT  USD_BAR         A  1970    0.00          M
# 112      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970    0.00          L
# 113      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970   37.65        NaN
# 114      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970   70.33        NaN
# 115      LTU  OILIMPPRICE     TOT  USD_BAR         A  1970   93.48        NaN
#
# [110 rows x 8 columns]

# %%
oil_price_pd['LOCATION'].replace(['AUS', 'AUT', 'LTU', 'LUX', 'BEL', 'CAN', 'CZE'],
                                  ['AUSTRALIA', 'AUSTRIA', 'LITHUANIA', 'LUXEMBOURG', 'BELGIUM', 'CANADA', 'CZECHIA'],
                                  inplace=True)

# %%
oil_price_pd
# Out:
#        LOCATION    INDICATOR SUBJECT  MEASURE FREQUENCY  TIME   Value  \
# 0     AUSTRALIA  OILIMPPRICE     TOT  USD_BAR         A  1970   70.21
# 1     AUSTRALIA  OILIMPPRICE     TOT  USD_BAR         A  1970   50.21
# 2     AUSTRALIA  OILIMPPRICE     TOT  USD_BAR         A  1970   72.04
# 3     AUSTRALIA  OILIMPPRICE     TOT  USD_BAR         A  1970  110.68
# 4       AUSTRIA  OILIMPPRICE     TOT  USD_BAR         A  1970   64.52
# ..          ...          ...     ...      ...       ...   ...     ...
# 108  LUXEMBOURG  OILIMPPRICE     TOT  USD_BAR         A  1970    0.00
# 112   LITHUANIA  OILIMPPRICE     TOT  USD_BAR         A  1970    0.00
# 113   LITHUANIA  OILIMPPRICE     TOT  USD_BAR         A  1970   37.65
# 114   LITHUANIA  OILIMPPRICE     TOT  USD_BAR         A  1970   70.33
# 115   LITHUANIA  OILIMPPRICE     TOT  USD_BAR         A  1970   93.48
#
#     Flag Codes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# ...

# %%
g = oil_price_pd.groupby('LOCATION')

# %%
mean_oil_price_pd = g['Value'].mean()
print(mean_oil_price_pd)
# Out:
# LOCATION
# AUSTRALIA     75.7850
# AUSTRIA       68.7750
# BELGIUM       69.6500
# CANADA        70.6275
# CHE           67.6000
# CZECHIA       67.2000
# DEU           69.1650
# DNK           71.0925
# ESP           69.0825
# EST            0.0000
# FIN           68.9200
# FRA           71.4450
# GBR           71.5150
# GRC           67.2400
# IRL           71.1100
# ITA           69.8250
# JPN           71.4975
# KOR           70.8550
# LITHUANIA     50.3650
# LUXEMBOURG     0.0000
# NLD           69.1975
# NOR           70.3875
# NZL           73.8875
# POL           66.4900
# PRT           72.7325
# SVK           61.9050
# SWE           71.8725
# TUR           69.3900
# USA           61.7600
# Name: Value, dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named oil_price_pd with columns 'TIME', 'LOCATION', and 'Value'
# and you want to plot the mean oil price for each country
mean_prices = oil_price_pd.groupby(['LOCATION', 'TIME'])['Value'].mean().unstack()

# Plotting
mean_prices.plot(kind='bar', figsize=(12, 8))
plt.title('Mean Oil Price by Country over the Years')
plt.xlabel('Country')
plt.ylabel('Mean Oil Price')
plt.legend(title='Year', bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named oil_price_pd with columns 'TIME', 'LOCATION', and 'Value'
# and you want to plot the mean oil price for each country
mean_prices = oil_price_pd.groupby(['LOCATION', 'TIME'])['Value'].mean().unstack()

# Calculate the mean oil price for each country and sort them in descending order
mean_prices_mean = mean_prices.mean(axis=1).sort_values(ascending=False)
mean_prices_sorted = mean_prices.loc[mean_prices_mean.index]

# Plotting
mean_prices_sorted.plot(kind='bar', figsize=(12, 8))
plt.title('Mean Oil Price by Country over the Years (Descending Order)')
plt.xlabel('Country')
plt.ylabel('Mean Oil Price')
plt.legend(title='Year', bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# %%
g.get_group('USA')
# Out:
#     LOCATION    INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 100      USA  OILIMPPRICE     TOT  USD_BAR         A  1970  56.33        NaN
# 101      USA  OILIMPPRICE     TOT  USD_BAR         A  1970  36.57        NaN
# 102      USA  OILIMPPRICE     TOT  USD_BAR         A  1970  64.43        NaN
# 103      USA  OILIMPPRICE     TOT  USD_BAR         A  1970  89.71        NaN

# %%
# Assuming oil_price_pd is your DataFrame and you want to find min and max for each location
min_max_values = oil_price_pd.groupby('LOCATION')['Value'].agg(['min', 'max'])
print(min_max_values)
# Out:
#               min     max
# LOCATION
# AUSTRALIA   50.21  110.68
# AUSTRIA     43.67   97.93
# BELGIUM     41.29  103.09
# CANADA      45.79  104.16
# CHE         46.72  104.00
# CZECHIA     45.91   88.84
# DEU         43.05   97.99
# DNK         42.37  105.93
# ESP         42.26  101.54
# EST          0.00    0.00
# FIN         40.55  101.45
# FRA         44.04  105.06
# GBR         44.62  104.66
# GRC         40.07   97.50
# IRL         43.71  104.42
# ITA         43.24   99.91
# JPN         46.85  102.11
# KOR         45.23  102.53
# LITHUANIA    0.00   93.48
# LUXEMBOURG   0.00    0.00
# NLD         42.38   99.42
# NOR         45.65   99.51
# NZL         51.28   97.27
# POL         41.31   91.46
# PRT         48.12  106.80
# SVK         41.67   73.77
# SWE         43.21  107.71
# TUR         43.41   97.83
# USA         36.57   89.71
