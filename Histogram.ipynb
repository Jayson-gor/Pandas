# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ages = [18, 18, 20, 19, 21, 22, 23, 25, 14, 25, 29, 30, 30, 28, 27, 27, 34, 35, 33, 33, 18, 22,21,21,20, 20,30]


plt.style.use('fivethirtyeight')
plt.hist(ages, bins = 5, edgecolor = 'black')
plt.title('Distribution of Ages')
# Out:
# Text(0.5, 1.0, 'Distribution of Ages')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ages = [18, 18, 20, 19, 21, 22, 23, 25, 14, 25, 29, 30, 30, 28, 27, 27, 34, 35, 33, 33, 18, 22,21,21,20, 20,30]
bins = [15,20,25,30,35]

plt.style.use('fivethirtyeight')
plt.hist(ages, bins = bins, edgecolor = 'black')
plt.title('Distribution of Ages')
# Out:
# Text(0.5, 1.0, 'Distribution of Ages')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ages = [18, 18, 20, 19, 21, 22, 23, 25, 14, 25, 29, 30, 30, 28, 27, 27, 34, 35, 33, 33, 18, 22,21,21,20, 20,30]
median_age = np.median(ages)

plt.axvline(median_age, color = 'red', label = 'Age Median')

plt.style.use('fivethirtyeight')
plt.hist(ages, bins = 5, edgecolor = 'black')
plt.title('Distribution of Ages')
plt.xlabel('Ages')
plt.legend()
plt.ylabel('Total Respondent')
# Out:
# Text(0, 0.5, 'Total Respondent')
